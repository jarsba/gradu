# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
CURRENT_FOLDER = os.path.dirname(os.path.dirname(os.path.abspath(__name__)))
RESULTS_FOLDER = os.path.join(CURRENT_FOLDER, "results")

# %%
timer_results_path = os.path.join(RESULTS_FOLDER, "napsu_MCMC_time_vs_epsilon_comparison.csv")
original_lr_results_path = os.path.join(RESULTS_FOLDER, "original_logistic_regression_results.csv")
synthetic_lr_results_path = os.path.join(RESULTS_FOLDER, "synthetic_logistic_regression_results.csv")

timer_results_df = pd.read_csv(timer_results_path)
original_lr_results_df = pd.read_csv(original_lr_results_path)
synthetic_lr_results_df = pd.read_csv(synthetic_lr_results_path)

# %%
timer_results_df
# Out:
#      Unnamed: 0 experiment_id         start          stop   timedelta  \
# 0             0      J9NST4D0  1.558460e+07  1.558501e+07  412.454065
# 1             1      J9NST4D0  1.558460e+07  1.558461e+07    8.468874
# 2             2      J9NST4D0  1.558461e+07  1.558461e+07    0.000192
# 3             3      J9NST4D0  1.558461e+07  1.558461e+07    0.052028
# 4             4      J9NST4D0  1.558461e+07  1.558498e+07  375.243121
# ..          ...           ...           ...           ...         ...
# 415         415      GN5KSIHK  1.560673e+07  1.560673e+07    7.416237
# 416         416      GN5KSIHK  1.560673e+07  1.560673e+07    0.000134
# 417         417      GN5KSIHK  1.560673e+07  1.560673e+07    0.005820
# 418         418      GN5KSIHK  1.560673e+07  1.560680e+07   67.767581
# 419         419      GN5KSIHK  1.560680e+07  1.560682e+07   22.816094
#
#                                 task dataset_name  query  epsilon  \
# 0                           Main run     binary4d  empty      0.1
# 1                    Query selection     binary4d    NaN      0.1
# 2    Calculating full marginal query     binary4d    NaN      0.1
# 3    Calculating canonical query set     binary4d    NaN      0.1
# 4              Laplace approximation     binary4d    NaN      0.1
# ..                               ...          ...    ...      ...
# 415                  Query selection     binary3d    NaN      8.0
# 416  Calculating full marginal query     binary3d    NaN      8.0
# 417  Calculating canonical query set     binary3d    NaN      8.0
# 418            Laplace approximation     binary3d    NaN      8.0
# 419                             MCMC     binary3d    NaN      8.0
#
#             delta MCMC_algo  laplace_approximation query_str  \
# 0    1.000000e-10      NUTS                   True       NaN
# 1    1.000000e-10      NUTS                   True     empty
# 2    1.000000e-10      NUTS                   True     empty
# 3    1.000000e-10      NUTS                   True     empty
# 4    1.000000e-10      NUTS                   True     empty
# ..            ...       ...                    ...       ...
# 415  1.000000e-10      NUTS                   True  AB+BC+AC
# 416  1.000000e-10      NUTS                   True  AB+BC+AC
# 417  1.000000e-10      NUTS                   True  AB+BC+AC
# 418  1.000000e-10      NUTS                   True  AB+BC+AC
# 419  1.000000e-10      NUTS                   True  AB+BC+AC
#
#                                query_list  n_canonical_queries
# 0                                     NaN                  NaN
# 1                                      []                  NaN
# 2                                      []                  NaN
# 3                                      []                  NaN
# 4                                      []                  7.0
# ..                                    ...                  ...
# 415  [['A', 'B'], ['B', 'C'], ['A', 'C']]                  NaN
# 416  [['A', 'B'], ['B', 'C'], ['A', 'C']]                  NaN
# 417  [['A', 'B'], ['B', 'C'], ['A', 'C']]                  NaN
# 418  [['A', 'B'], ['B', 'C'], ['A', 'C']]                  6.0
# 419  [['A', 'B'], ['B', 'C'], ['A', 'C']]                  6.0
#
# [420 rows x 15 columns]

# %%
original_lr_results_df
# Out:
#   dataset_name                              accuracy  \
# 0     binary4d  [0.7678 0.7664 0.7702 0.7672 0.7665]
# 1     binary3d  [0.6134 0.6212 0.6156 0.6111 0.6164]
#
#                                    balanced_accuracy  \
# 0  [0.59331879 0.5        0.60039019 0.59620009 0...
# 1  [0.61873112 0.56656465 0.56366211 0.61780554 0...
#
#                                                   F1  \
# 0  [0.85872475 0.86775362 0.85975833 0.8579275  0...
# 1  [0.65401826 0.72330168 0.71660277 0.65004949 0...
#
#                               coefficients  \
# 0  [[ 1.02625708 -0.00650265  2.00140714]]
# 1              [[ 1.01258733 -0.00628954]]
#
#                            point_estimates  \
# 0  [[ 1.02258994 -0.01088867  1.99866304]]
# 1              [[ 1.01333173 -0.005663  ]]
#
#                      variance_estimates  \
# 0  [[0.00021074 0.00018442 0.00030877]]
# 1             [[0.00013077 0.00011474]]
#
#                                 confidence_intervals
# 0  {0.95: array([[[ 0.99413761,  1.05104227],\n  ...
# 1  {0.95: array([[[ 0.99091841,  1.03574506],\n  ...

# %%
synthetic_lr_results_df
# Out:
#     experiment_id dataset_name  dataset_index  \
# 0        J9NST4D0     binary4d            0.0
# 1        J9NST4D0     binary4d            1.0
# 2        J9NST4D0     binary4d            2.0
# 3        J9NST4D0     binary4d            3.0
# 4        J9NST4D0     binary4d            4.0
# ..            ...          ...            ...
# 765      GN5KSIHK     binary3d            6.0
# 766      GN5KSIHK     binary3d            7.0
# 767      GN5KSIHK     binary3d            8.0
# 768      GN5KSIHK     binary3d            9.0
# 769      GN5KSIHK     binary3d            NaN
#
#                                     query  epsilon MCMC_algorithm  \
# 0                                      []      0.1           NUTS
# 1                                      []      0.1           NUTS
# 2                                      []      0.1           NUTS
# 3                                      []      0.1           NUTS
# 4                                      []      0.1           NUTS
# ..                                    ...      ...            ...
# 765  [['A', 'B'], ['B', 'C'], ['A', 'C']]      8.0           NUTS
# 766  [['A', 'B'], ['B', 'C'], ['A', 'C']]      8.0           NUTS
# 767  [['A', 'B'], ['B', 'C'], ['A', 'C']]      8.0           NUTS
# 768  [['A', 'B'], ['B', 'C'], ['A', 'C']]      8.0           NUTS
# 769  [['A', 'B'], ['B', 'C'], ['A', 'C']]      8.0           NUTS
#
#                                  accuracy  \
# 0    [0.7678 0.7664 0.7702 0.7672 0.7665]
# 1    [0.7678 0.7664 0.7702 0.7672 0.7665]
# 2    [0.7678 0.7664 0.7702 0.7672 0.7665]
# 3    [0.7678 0.7664 0.7702 0.7672 0.7665]
# 4    [0.7678 0.7664 0.7702 0.7672 0.7665]
# ..                                    ...
# 765  [0.6134 0.6212 0.6156 0.6111 0.6164]
# 766  [0.6134 0.6212 0.6156 0.6111 0.6164]
# 767  [0.6134 0.6212 0.6156 0.6111 0.6164]
# 768  [0.6134 0.6212 0.6156 0.6111 0.6164]
# 769  [0.6134 0.6212 0.6156 0.6111 0.6164]
#
#                                      balanced_accuracy  \
# 0    [0.59331879 0.5        0.60039019 0.59620009 0...
# 1    [0.59331879 0.5        0.60039019 0.59620009 0...
# 2    [0.59331879 0.5        0.60039019 0.59620009 0...
# 3    [0.59331879 0.5        0.60039019 0.59620009 0...
# 4    [0.59331879 0.5        0.60039019 0.59620009 0...
# ..                                                 ...
# 765  [0.61873112 0.56656465 0.56366211 0.61780554 0...
# 766  [0.61873112 0.56656465 0.56366211 0.61780554 0...
# 767  [0.61873112 0.56656465 0.56366211 0.61780554 0...
# 768  [0.61873112 0.56656465 0.56366211 0.61780554 0...
# 769  [0.61873112 0.56656465 0.56366211 0.61780554 0...
#
#                                                     F1  \
# 0    [0.85872475 0.86775362 0.85975833 0.8579275  0...
# 1    [0.85872475 0.86775362 0.85975833 0.8579275  0...
# 2    [0.85872475 0.86775362 0.85975833 0.8579275  0...
# 3    [0.85872475 0.86775362 0.85975833 0.8579275  0...
# 4    [0.85872475 0.86775362 0.85975833 0.8579275  0...
# ..                                                 ...
# 765  [0.65401826 0.72330168 0.71660277 0.65004949 0...
# 766  [0.65401826 0.72330168 0.71660277 0.65004949 0...
# 767  [0.65401826 0.72330168 0.71660277 0.65004949 0...
# 768  [0.65401826 0.72330168 0.71660277 0.65004949 0...
# 769  [0.65401826 0.72330168 0.71660277 0.65004949 0...
#
#                                           coefficients  \
# 0    [[ 8.57200542e-01 -1.70604644e-03  1.87110943e...
# 1                 [[0.88559874 0.01353439 1.81487827]]
# 2                 [[0.9167418  0.00329622 1.92848061]]
# 3              [[ 0.80282827 -0.00764482  1.93114483]]
# 4              [[ 0.87715121 -0.01903948  1.84408769]]
# ..                                                 ...
# 765                          [[1.00359615 0.00415937]]
# 766                [[ 1.03181527e+00 -1.91288629e-04]]
# 767                          [[1.03153139 0.01472146]]
# 768                        [[ 1.00686525 -0.00698123]]
# 769                        [[ 1.01050303 -0.0054389 ]]
#
#                                        point_estimates  \
# 0                 [[0.93952818 0.0910975  1.93964098]]
# 1                 [[0.93639179 0.0706775  1.85890114]]
# 2                 [[0.95569345 0.04769811 1.9610968 ]]
# 3                 [[0.85785964 0.05379267 1.97646288]]
# 4                 [[0.9576154  0.07125291 1.91188009]]
# ..                                                 ...
# 765                          [[1.00502759 0.00556746]]
# 766                        [[ 1.02864629 -0.00400135]]
# 767                  [[1.01871332e+00 4.91295381e-05]]
# 768                        [[ 1.004618   -0.00971249]]
# 769  [[ 1.02269225e+00 -1.15792826e-02]\n [ 1.01256...
#
#                                     variance_estimates  \
# 0                 [[0.000211   0.00017982 0.00030786]]
# 1                 [[0.00020824 0.00017862 0.00028544]]
# 2                 [[0.00021334 0.00017881 0.00031174]]
# 3                 [[0.00020408 0.00017798 0.00030495]]
# 4                 [[0.00021052 0.00018112 0.00030001]]
# ..                                                 ...
# 765                          [[0.00013155 0.00011498]]
# 766                          [[0.00013179 0.00011436]]
# 767                          [[0.00013189 0.00011488]]
# 768                          [[0.00013033 0.00011457]]
# 769  [[0.00013166 0.00011458]\n [0.00013087 0.00011...
#
#                                   confidence_intervals
# 0    {0.95: array([[[0.91105838, 0.96799798],\n    ...
# 1    {0.95: array([[[0.90810841, 0.96467518],\n    ...
# 2    {0.95: array([[[0.92706586, 0.98432103],\n    ...
# 3    {0.95: array([[[0.82986036, 0.88585891],\n    ...
# 4    {0.95: array([[[0.92917749, 0.98605332],\n    ...
# ..                                                 ...
# 765  {0.95: array([[[ 0.98254814,  1.02750705],\n  ...
# 766  {0.95: array([[[ 1.00614593,  1.05114666],\n  ...
# 767  {0.95: array([[[ 0.99620407,  1.04122258],\n  ...
# 768  {0.95: array([[[ 0.98224283,  1.02699317],\n  ...
# 769  {0.95: array([[[ 1.0002027 ,  1.0451818 ],\n  ...
#
# [770 rows x 13 columns]

# %%
synthetic_3d_lr_results_df =

# %%
colors = plt.rcParams["axes.prop_cycle"].by_key()["color"]
plt.subplots(figsize=(16, 10))
for index, row in synthetic_lr_results_df.iterrows():
    print(row)
    #plt.errorbar(synthetic_lr_coefficient_mean, y=[f"Synthetic - Coefficient {i}"], xerr=synthetic_lr_coefficient_radius, fmt=".", color=colors[i])
    #plt.errorbar(original_lr_coefficient_mean, y=[f"Original- Coefficient {i}"], xerr=original_lr_coefficient_radius, fmt=".", color=colors[i])

plt.xticks(range(-6, 7))
plt.tight_layout()
plt.show()
# Out:
# experiment_id
# dataset_name
# dataset_index
# query
# epsilon
# MCMC_algorithm
# accuracy
# balanced_accuracy
# F1
# coefficients
# point_estimates
# variance_estimates
# confidence_intervals
