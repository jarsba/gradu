# %%
import sys
sys.path.append("/home/jarlehti/projects/gradu")

# %%
import statsmodels.api as sm
import numpy as np
import os
import sys
import pandas as pd
from src.utils.preprocess_dataset import clean_adult, clean_adult_with_discretization
from src.utils.data_utils import transform_for_classification, transform_for_ci_coverage

# %%
CURRENT_FOLDER = os.path.dirname(os.path.dirname(os.path.abspath(__name__)))
SYN_DATA_FOLDER = os.path.join(CURRENT_FOLDER, "data", "synt_datasets")
DATASETS_FOLDER = os.path.join(CURRENT_FOLDER, "data", "datasets")

# %%
binary3d_df = pd.read_csv(os.path.join(DATASETS_FOLDER, 'binary3d.csv'))
binary4d_df = pd.read_csv(os.path.join(DATASETS_FOLDER, 'binary4d.csv'))
adult_df = pd.read_csv(os.path.join(DATASETS_FOLDER, 'cleaned_adult_train_data.csv'))

# %%
adult_df = clean_adult(adult_df)

# %%
adult_df
# Out:
#        age         workclass education-num      marital-status  \
# 0       39         State-gov            13       Never-married
# 1       50  Self-emp-not-inc            13  Married-civ-spouse
# 2       38           Private             9            Divorced
# 3       53           Private             7  Married-civ-spouse
# 4       28           Private            13  Married-civ-spouse
# ...    ...               ...           ...                 ...
# 30157   27           Private            12  Married-civ-spouse
# 30158   40           Private             9  Married-civ-spouse
# 30159   58           Private             9             Widowed
# 30160   22           Private             9       Never-married
# 30161   52      Self-emp-inc             9  Married-civ-spouse
#
#               occupation   relationship   race     sex  capital-gain  \
# 0           Adm-clerical  Not-in-family  White    Male          2174
# ...

# %%
adult_df.dtypes
# Out:
# age                      int64
# workclass             category
# education-num         category
# marital-status        category
# occupation            category
# relationship          category
# race                  category
# sex                   category
# capital-gain             int64
# capital-loss             int64
# hours-per-week           int64
# native-country        category
# had-capital-gains        int64
# had-capital-losses       int64
# compensation          category
# dtype: object

# %%
adult_df.columns
# Out:
# Index(['age', 'workclass', 'education-num', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'native-country', 'had-capital-gains',
#        'had-capital-losses', 'compensation'],
#       dtype='object')

# %%
adult_transformed = transform_for_classification("adult_no_discretization", adult_df)

# %%
adult_transformed
# Out:
#        age  education-num  capital-gain  capital-loss  hours-per-week  \
# 0       39             13          2174             0              40
# 1       50             13             0             0              13
# 2       38              9             0             0              40
# 3       53              7             0             0              40
# 4       28             13             0             0              40
# ...    ...            ...           ...           ...             ...
# 30157   27             12             0             0              38
# 30158   40              9             0             0              40
# 30159   58              9             0             0              40
# 30160   22              9             0             0              20
# 30161   52              9         15024             0              40
#
#        had-capital-gains  had-capital-losses  workclass_Federal-gov  \
# ...

# %%
adult_transformed.dtypes
# Out:
# age                               int64
# education-num                     int64
# capital-gain                      int64
# capital-loss                      int64
# hours-per-week                    int64
#                                   ...
# native-country_Trinadad&Tobago    uint8
# native-country_United-States      uint8
# native-country_Vietnam            uint8
# native-country_Yugoslavia         uint8
# compensation                      int64
# Length: 90, dtype: object

# %%
adult_df.columns
# Out:
# Index(['age', 'workclass', 'education-num', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'capital-gain', 'capital-loss',
#        'hours-per-week', 'native-country', 'had-capital-gains',
#        'had-capital-losses', 'compensation'],
#       dtype='object')

# %%
adult_df_dicretized = clean_adult_with_discretization(adult_df, columns=adult_df.columns)

# %%
adult_df_dicretized
# Out:
#            age         workclass education-num      marital-status  \
# 0      30 - 40         State-gov            13       Never-married
# 1      50 - 60  Self-emp-not-inc            13  Married-civ-spouse
# 2      30 - 40           Private             9            Divorced
# 3      50 - 60           Private             7  Married-civ-spouse
# 4      20 - 30           Private            13  Married-civ-spouse
# ...        ...               ...           ...                 ...
# 30157  20 - 30           Private            12  Married-civ-spouse
# 30158  40 - 50           Private             9  Married-civ-spouse
# 30159  50 - 60           Private             9             Widowed
# 30160  20 - 30           Private             9       Never-married
# 30161  50 - 60      Self-emp-inc             9  Married-civ-spouse
#
#               occupation   relationship   race     sex  capital-gain  \
# 0           Adm-clerical  Not-in-family  White    Male          2174
# ...

# %%
adult_discretized_transformed = transform_for_classification("adult_high_discretization", adult_df_dicretized)

# %%
adult_discretized_transformed.columns
# Out:
# Index(['capital-gain', 'capital-loss', 'had-capital-gains',
#        'had-capital-losses', 'age_0 - 10', 'age_10 - 20', 'age_20 - 30',
#        'age_30 - 40', 'age_40 - 50', 'age_50 - 60',
#        ...
#        'native-country_Puerto-Rico', 'native-country_Scotland',
#        'native-country_South', 'native-country_Taiwan',
#        'native-country_Thailand', 'native-country_Trinadad&Tobago',
#        'native-country_United-States', 'native-country_Vietnam',
#        'native-country_Yugoslavia', 'compensation'],
#       dtype='object', length=123)

# %%
X_train_adult = adult_df.drop(columns=['compensation'])
y_train_adult = adult_df['compensation']

# %%
model = sm.GLM(y_train_adult, X_train_adult, family=sm.families.Binomial())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 model = sm.GLM(y_train_adult, X_train_adult, family=sm.families.Binomial())
#
# File /home/local/jarlehti/projects/gradu/venv/lib/python3.8/site-packages/statsmodels/genmod/generalized_linear_model.py:316, in GLM.__init__(self, endog, exog, family, offset, exposure, freq_weights, var_weights, missing, **kwargs)
#     313 self.freq_weights = freq_weights
#     314 self.var_weights = var_weights
# --> 316 super(GLM, self).__init__(endog, exog, missing=missing,
#     317                           offset=offset, exposure=exposure,
#     318                           freq_weights=freq_weights,
#     319                           var_weights=var_weights, **kwargs)
#     320 self._check_inputs(family, self.offset, self.exposure, self.endog,
#     321                    self.freq_weights, self.var_weights)
# ...

# %%
adult_df_dicretized_ci = transform_for_ci_coverage("adult_high_discretization", adult_df_dicretized)

# %%
adult_df_dicretized_ci
# Out:
#        age  workclass  education-num  marital-status  occupation  \
# 0        3          5             12               4           0
# 1        5          4             12               2           3
# 2        3          2              8               0           5
# 3        5          2              6               2           5
# 4        2          2             12               2           9
# ...    ...        ...            ...             ...         ...
# 30157    2          2             11               2          12
# 30158    4          2              8               2           6
# 30159    5          2              8               6           0
# 30160    2          2              8               4           0
# 30161    5          3              8               2           3
#
#        relationship  race  sex  capital-gain  capital-loss  hours-per-week  \
# 0                 1     4    1          2174             0               4
# ...

# %%
adult_df_dicretized_ci.dtypes
# Out:
# age                    int8
# workclass              int8
# education-num          int8
# marital-status         int8
# occupation             int8
# relationship           int8
# race                   int8
# sex                    int8
# capital-gain          int64
# capital-loss          int64
# hours-per-week         int8
# native-country         int8
# had-capital-gains     int64
# had-capital-losses    int64
# compensation          int64
# dtype: object
